# %% [markdown]
# # Exercise-1

# %%
import pandas as pd
import numpy as np

# %%
#A
data=pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv",header=0)

# %%
#B
data.columns=["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
 "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
 "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
 "peak-rpm","city-mpg","highway-mpg","price"]

#C
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
#D
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#E
obj_col=data.select_dtypes('object').columns
for i in obj_col:
    data[i]=data[i].replace("?",np.nan)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
#F
data.isnull().sum()[data.isnull().sum()>0]
# Out:
# normalized-losses    40
# num-of-doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak-rpm              2
# price                 4
# dtype: int64

# %%
#G
data=data.dropna(subset=["price"])

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.isnull().sum()[data.isnull().sum()>0]
# Out:
# normalized-losses    36
# num-of-doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak-rpm              2
# dtype: int64

# %%
#H
data[['normalized-losses','bore','stroke','horsepower','peak-rpm']]=data[['normalized-losses','bore','stroke','horsepower','peak-rpm']].astype('float64')

# %%
data['normalized-losses'] = data['normalized-losses'].fillna((data['normalized-losses'].mean()))
data['bore'] = data['bore'].fillna((data['bore'].mean()))
data['stroke'] = data['stroke'].fillna((data['stroke'].mean()))
data['horsepower'] = data['horsepower'].fillna((data['horsepower'].mean()))
data['peak-rpm'] = data['peak-rpm'].fillna((data['peak-rpm'].mean()))

# %%
#I
data['num-of-doors']=data['num-of-doors'].fillna(data['num-of-doors'].mode()[0],inplace=True)

# %%
#J
data.reset_index(inplace=True)

# %%
#K
data.dtypes
# Out:
# index                  int64
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data['price']=data['price'].astype('int64')

# %%
data.dtypes
# Out:
# index                  int64
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
#L
data['city-L/100km']=data['city-mpg']/100
data['highway-L/100km']=data['highway-mpg']/100

# %%
#M
data['length']=data['length']/data['length'].max()
data['width']=data['width']/data['width'].max()
data['height']=data['height']/data['height'].max()

# %%
#N
data['horsepower'].hist()

# %%
#O and P
data['horse-binned']=pd.qcut(data['horsepower'],q=3,labels=['Low','Medium','High'])
data['horse-binned'].hist()

# %%
#Q
col=['fuel-type','aspiration']
data=pd.concat([data.drop(col, axis=1),pd.get_dummies(data[col])],axis=1)
data.head()
# Out:
#    index  symboling  normalized-losses         make num-of-doors   body-style  \
# 0      0          3              122.0  alfa-romero         None  convertible
# 1      1          1              122.0  alfa-romero         None    hatchback
# 2      2          2              164.0         audi         None        sedan
# 3      3          2              164.0         audi         None        sedan
# 4      4          2              122.0         audi         None        sedan
#
#   drive-wheels engine-location  wheel-base    length  ...  peak-rpm  city-mpg  \
# 0          rwd           front        88.6  0.811148  ...    5000.0        21
# 1          rwd           front        94.5  0.822681  ...    5000.0        19
# 2          fwd           front        99.8  0.848630  ...    5500.0        24
# 3          4wd           front        99.4  0.848630  ...    5500.0        18
# 4          fwd           front        99.8  0.851994  ...    5500.0        19
#
# ...

# %% [markdown]
# # Exercise-2

# %%
#1
data1=pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv")
data1
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
#2
import matplotlib as plt
import seaborn as sns

# %%
#3
print(data1.shape)
print(data1.dtypes)
# Out:
# (201, 29)
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#4
from scipy.stats import pearsonr
corr, _ = pearsonr(data1['engine-size'],data1['price'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.872

# %%
#5
data1.corr()['price']
# Out:
# symboling           -0.082391
# normalized-losses    0.133999
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# height               0.135486
# curb-weight          0.834415
# engine-size          0.872335
# bore                 0.543155
# stroke               0.082310
# compression-ratio    0.071107
# horsepower           0.809575
# peak-rpm            -0.101616
# city-mpg            -0.686571
# highway-mpg         -0.704692
# price                1.000000
# city-L/100km         0.789898
# diesel               0.110326
# gas                 -0.110326
# Name: price, dtype: float64

# %%
#6
data1['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
#7
sns.regplot(data1['engine-size'],data1['price'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#8
sns.pairplot(data1, y_vars=['price'], x_vars=data1.select_dtypes('float64').columns, kind='reg')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ...

# %%
#10
sns.heatmap(data1.corr())

# %%
#11
sns.boxplot(x=data1["price"],y=data1["body-style"])

# %%
#12
sns.boxplot(x=data1["price"],y=data1["engine-type"])

# %%
sns.boxplot(x=data1["price"],y=data1["num-of-doors"])

# %%
sns.boxplot(x=data1["price"],y=data1["drive-wheels"])

# %%
sns.boxplot(x=data1["price"],y=data1["num-of-cylinders"])

# %%
sns.boxplot(x=data1["price"],y=data1["fuel-system"])

# %%
#13
"""""
Boxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and
how tightly our data is grouped.
from the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each
unique categorical values in each column and how much they vary from each other w.r.t price.

"""""

# %%
#14
data1.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
#15
data1.describe(include='object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
#16
cat_col=data1.columns[data1.dtypes=='object']
for i in cat_col:
    print(str(i)+' column unique values are :\n'+str(data1[i].value_counts()))
    print('\n')
    
"""""
From below we get to know unique categorical values in each column and number of times it appeared in that column.
It shows which brand of car is more popular, which engine-type, fuel-type, etc. is preffered by the customers.
For instance, 86 cars have 2 doors, so we can say that, its most likely a sports car or very expensive car, 
as number of seats in sports car is less than normal cars.
"""""
# Out:
# make column unique values are :
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# volvo            11
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
#
#
# aspiration column unique values are :
# std      165
# turbo     36
# Name: aspiration, dtype: int64
#
#
# num-of-doors column unique values are :
# four    115
# two      86
# Name: num-of-doors, dtype: int64
#
#
# body-style column unique values are :
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64
#
#
# drive-wheels column unique values are :
# fwd    118
# ...

# %%
#17
data1.groupby('drive-wheels').mean()['price']
# Out:
# drive-wheels
# 4wd    10241.000000
# fwd     9244.779661
# rwd    19757.613333
# Name: price, dtype: float64

# %%
#18
for i in cat_col:
    print(data1.groupby(i).mean()['price'])
    print('\n')
# Out:
# make
# alfa-romero      15498.333333
# audi             17859.166667
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          31400.500000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64
#
#
# aspiration
# std      12542.181818
# turbo    16254.805556
# Name: price, dtype: float64
#
#
# num-of-doors
# four    13498.034783
# two     12818.127907
# Name: price, dtype: float64
#
#
# body-style
# convertible    21890.500000
# ...

# %%
#19 
gb=data1.groupby(['drive-wheels','body-style']).mean()['price']
gb
# Out:
# drive-wheels  body-style
# 4wd           hatchback       7603.000000
#               sedan          12647.333333
#               wagon           9095.750000
# fwd           convertible    11595.000000
#               hardtop         8249.000000
#               hatchback       8396.387755
#               sedan           9811.800000
#               wagon           9997.333333
# rwd           convertible    23949.600000
#               hardtop        24202.714286
#               hatchback      14337.777778
#               sedan          21711.833333
#               wagon          16994.222222
# Name: price, dtype: float64

# %%
#20
gb.reset_index().pivot_table(index='drive-wheels',columns='body-style')
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#21
gb1=data1.groupby(['engine-location','engine-type']).mean()['price']
gb1.reset_index().pivot_table(index='engine-location',columns='engine-type')
# Out:
#                         price                                        \
# engine-type              dohc             l           ohc      ohcf
# engine-location
# front            18116.416667  14627.583333  11567.358621   8541.25
# rear                      NaN           NaN           NaN  34528.00
#
#
# engine-type              ohcv    rotor
# engine-location
# front            25098.384615  13020.0
# rear                      NaN      NaN

# %%
gb2=data1.groupby(['fuel-system','horsepower-binned']).mean()['price']
gb2.reset_index().pivot_table(index='fuel-system',columns='horsepower-binned')
# Out:
#                           price
# horsepower-binned          High           Low        Medium
# fuel-system
# 1bbl                        NaN   7555.545455           NaN
# 2bbl                        NaN   7433.203125           NaN
# 4bbl                        NaN  12145.000000           NaN
# idi                         NaN  12047.800000  27209.200000
# mfi                         NaN           NaN  12964.000000
# mpfi               25899.130435  11871.904762  15716.659574
# spdi                        NaN           NaN  10990.444444
# spfi                        NaN  11048.000000           NaN

# %%
#22
sns.heatmap(gb.reset_index().pivot_table(index='drive-wheels',columns='body-style'))

# %%
#23
from scipy.stats import pearsonr
corr, _ = pearsonr(data1['wheel-base'],data1['price'])
print('Pearsons correlation: %.3f' % corr)
""""
a p-value helps us determine the significance of our results.
# Out:
# Pearsons correlation: 0.585

# %%
#24
from scipy.stats import f_oneway
f_oneway(data1['price'][data1['drive-wheels'] == '4wd'],
               data1['price'][data1['drive-wheels'] == 'fwd'],
               data1['price'][data1['drive-wheels'] == 'rwd'])
""""
F-statistic=67.95 suggests the between-groups variance is 67x the within-group variance
p-value is <0.05, so we reject null hypothesis i.e, both are correlated and the result is significant .
""""
# Out:
# F_onewayResult(statistic=67.95406500780399, pvalue=3.3945443577151245e-23)
